# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2022_DataScience/blob/main/WordCloud_%EC%82%BC%EA%B5%AD%EC%A7%80_%EC%96%B4%EB%A6%B0%EC%99%95%EC%9E%90%ED%85%8D%EC%8A%A4%ED%8A%B8%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #konlpy
# - 한국어를 처리하는 대표적인 형태소 분석 패키지

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 89.7 MB/s
# ...
#      |████████████████████████████████| 453 kB 86.9 MB/s
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np
from google.colab import files

# %% [markdown]
# #삼국지 책의 내용 중 단어의 등장하는 횟수를 센다(텍스트를 메모장에서 utf-8 인코딩 방식으로 저장해야함)

# %%
with open('text33.txt', 'r', encoding='utf-8') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
print(c)
# Out:
# Counter({'조조': 348, '유비': 344, '사람': 290, '동탁': 240, '장비': 194, '다시': 180, '손견': 179, '군사': 173, '원소': 144, '도적': 120, '생각': 116, '자신': 114, '하진': 114, '환관': 111, '거기': 107, '마음': 105, '하나': 104, '때문': 102, '우리': 95, '관우': 93, '이름': 88, '백성': 88, '이제': 87, '자기': 86, '무리': 84, '노식': 84, '어찌': 82, '대답': 82, '크게': 82, '자리': 79, '황제': 79, '현덕': 78, '이오': 76, '먼저': 75, '모두': 72, '천하': 70, '다가': 70, '또한': 69, '조정': 69, '시작': 69, '무슨': 68, '여포': 68, '바로': 66, '태수': 65, '더욱': 64, '싸움': 64, '세상': 63, '얼굴': 63, '나라': 62, '그때': 62, '한번': 61, '대신': 61, '장수': 61, '벼슬': 59, '십상시': 59, '무엇': 58, '주전': 58, '소리': 56, '하늘': 55, '지금': 55, '낙양': 55, '황건적': 54, '형제': 53, '가지': 52, '아들': 52, '정원': 52, '역시': 51, '목소리': 50, '장보': 49, '위해': 48, '스스로': 48, '사이': 47, '반드시': 46, '의군': 46, '독우': 46, '공손찬': 45, '아우': 45, '수가': 44, '오히려': 44, '스승': 44, '아래': 44, '이유': 44, '여러': 43, '시오': 43, '었다': 42, '장각': 41, '처음': 40, '다른': 40, '보고': 40, '비록': 40, '정도': 40, '자가': 39, '가운데': 39, '대장군': 39, '까닭': 39, '실로': 39, '늙
# ...

# %% [markdown]
# #한글 폰트 설치 필요

# %%
#폰트설치
# !apt -get update --qq
# !apt-get install fonts-nanum* -qq
# Out:
# E: Command line option 'g' [from -get] is not understood in combination with the other options.

# %%
path='/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
wc = WordCloud(font_path=path, width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)

plt.figure(figsize=(10,10))
plt.imshow(gen, interpolation='bilinear')
plt.axis("off")

# plt.savefig('333.png')  #이미지로 저장
# files.download('333.png') #내컴퓨터로 다운로드

plt.show()

# %% [markdown]
# #마스크 이미지 로드

# %%
import numpy as np
from PIL import Image
from wordcloud import STOPWORDS

mask333=np.array(Image.open("mask.png"))
stopwords=set(STOPWORDS)
# stopwords.add("said")

plt.figure(figsize=(10,10))
plt.imshow(mask333,cmap=plt.cm.gray,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
path='/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
# wc = WordCloud(font_path=path, background_color="white",mask=mask333, max_font_size=100)

wc=WordCloud(font_path=path, background_color="white",max_words=2000,mask=mask333,stopwords=stopwords)
wc=wc.generate(text)

plt.figure(figsize=(10,10))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")

# plt.savefig('3.png')  #이미지로 저장
# files.download('3.png') #내컴퓨터로 다운로드

plt.show()

# %% [markdown]
# #어린왕자 영어 책 내용 워드 클라우드 분석

# %%
import operator
import string
#1. 어린왕자 텍스트 파일을 읽어와서 단어가 등장하는 횟수 카운트(counts 딕셔너리에 저장)
f = open('test33.txt', encoding='utf-8')
counts = dict()
for line in f:
    line = line.rstrip()
    line = line.translate(line.maketrans('', '', string.punctuation))
    line = line.lower()
    words = line.split()
    for word in words:
        if word not in counts:
            counts[word] = 1
        else:
            counts[word] += 1

print(counts)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-f4ab117342ed> in <module>
#       4 f = open('test33.txt', encoding='utf-8')
#       5 counts = dict()
# ----> 6 for line in f:
#       7     line = line.rstrip()
#       8     line = line.translate(line.maketrans('', '', string.punctuation))
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbb in position 8: invalid start byte

# %% [markdown]
# #단어의 횟수에 따라 많은 순으로 정렬

# %%
#2. counts 딕셔너리의 등장 횟수 '값'에 따라 정렬
sorted_counts = sorted(counts.items(), key=operator.itemgetter(1), reverse = True) 
print(sorted_counts[:100])
# Out:
# [('the', 829), ('i', 403), ('a', 396), ('to', 366), ('and', 333), ('of', 278), ('he', 255), ('you', 252), ('little', 232), ('prince', 171), ('that', 166), ('was', 161), ('said', 158), ('my', 143), ('but', 140), ('it', 136), ('for', 132), ('in', 130), ('me', 114), ('is', 107), ('on', 105), ('be', 102), ('his', 97), ('one', 96), ('have', 90), ('at', 85), ('all', 85), ('its', 83), ('are', 82), ('what', 77), ('if', 75), ('so', 74), ('as', 71), ('they', 69), ('then', 69), ('had', 69), ('no', 65), ('this', 65), ('planet', 65), ('him', 64), ('very', 61), ('not', 59), ('with', 58), ('like', 58), ('them', 57), ('im', 57), ('when', 53), ('from', 49), ('do', 49), ('flower', 49), ('by', 48), ('there', 45), ('good', 45), ('your', 43), ('never', 42), ('an', 41), ('who', 41), ('stars', 40), ('out', 40), ('too', 39), ('time', 38), ('would', 38), ('know', 38), ('sheep', 38), ('up', 37), ('where', 37), ('can', 36), ('just', 36), ('fox', 35), ('again', 33), ('dont', 33), ('about', 32), ('asked', 32), (
# ...

# %% [markdown]
# #빈도수가 많은 단어가 크기순으로 워드클라우드를 생성

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from google.colab import files
from wordcloud import WordCloud

text=open('thelittleprince.txt').read()
wordcloud=WordCloud().generate(text)

wordcloud.words_
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.savefig('cloud1.png')  #이미지로 저장
files.download('cloud1.png') #내컴퓨터로 다운로드

plt.show()

# %% [markdown]
# #어린왕자 이미지를 마스크로 만들어 워드클라우드를 생성

# %%
import numpy as np
from PIL import Image
from wordcloud import STOPWORDS

prince_mask=np.array(Image.open("littleprince_mask.jpg"))
stopwords=set(STOPWORDS)
stopwords.add("said")
prince_mask
# Out:
# array([[[255, 255, 231],
#         [255, 255, 231],
#         [255, 254, 233],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 231],
#         [255, 254, 233],
#         [255, 254, 233],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 254, 233],
#         [255, 254, 233],
#         [255, 254, 233],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 253],
#         [255, 255, 253],
#         [255, 255, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# #마스크 이미지 보기

# %%
plt.figure(figsize=(8,8))
plt.imshow(prince_mask,cmap=plt.cm.gray,interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# #워드클라우드를 생성할 단어들의 빈도수에 따른 크기

# %%
wc=WordCloud(background_color="white",max_words=2000,mask=prince_mask,stopwords=stopwords)
wc=wc.generate(text)
wc.words_
# Out:
# {'little prince': 1.0,
#  'one': 0.6089385474860335,
#  'planet': 0.39106145251396646,
#  'flower': 0.35195530726256985,
#  'star': 0.2849162011173184,
#  'little': 0.2346368715083799,
#  'know': 0.2122905027932961,
#  'sheep': 0.2122905027932961,
#  'time': 0.2011173184357542,
#  'never': 0.19553072625698323,
#  'king': 0.19553072625698323,
#  'fox': 0.19553072625698323,
#  'day': 0.18994413407821228,
#  'asked': 0.1787709497206704,
#  'made': 0.16759776536312848,
#  'nothing': 0.16201117318435754,
#  'good': 0.15083798882681565,
#  'make': 0.1452513966480447,
#  'course': 0.1452513966480447,
#  'come': 0.1452513966480447,
#  'people': 0.13966480446927373,
#  'see': 0.13966480446927373,
#  'way': 0.13966480446927373,
#  'friend': 0.13966480446927373,
#  'will': 0.13966480446927373,
#  'well': 0.13966480446927373,
#  'now': 0.13966480446927373,
#  'answered': 0.1340782122905028,
#  'thing': 0.1340782122905028,
#  'understand': 0.12849162011173185,
#  'quite': 0.12849162011173185,
# ...

# %% [markdown]
# #마스크 이미지에 워드클라우드 생성

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")

plt.savefig('cloud2.png')  #이미지로 저장
files.download('cloud2.png') #내컴퓨터로 다운로드

plt.show()

# %% [markdown]
# #흑백으로 만들기

# %%
# BLACK BACKGROUND WITH GREY LETTERS
import random
# text=open('thelittleprince.txt').read()

def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

wc=WordCloud(background_color="white",max_words=2000,mask=prince_mask,stopwords=stopwords)
wc=wc.generate(text)
wc.recolor(color_func=grey_color_func)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")

plt.savefig('cloud3.png')  #이미지로 저장
files.download('cloud3.png') #내컴퓨터로 다운로드

plt.show()
