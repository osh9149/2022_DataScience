# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2022_DataScience/blob/main/4%EB%8B%A8%EC%9B%90(DNN%EB%AA%A8%EB%8D%B8%EB%A7%8C%EB%93%A4%EA%B8%B0_p208).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf

# %%
# seed 값 생성
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 로드
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
X = dataset[:,0:8]  #맨마지막 class 전까지의 데이터를 X로 지정
Y = dataset[:,8]  #맨마지막에 있는 class 데이터를 Y로 지정
print(X)
print(Y)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))  #input_dim 는 데이터의 속성 개수
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
# 모델 실행
model.fit(X, Y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 77/77 [==============================] - 1s 2ms/step - loss: 7.0523 - accuracy: 0.6211
# Epoch 2/200
# 77/77 [==============================] - 0s 2ms/step - loss: 2.0855 - accuracy: 0.6185
# Epoch 3/200
# 77/77 [==============================] - 0s 2ms/step - loss: 1.3581 - accuracy: 0.5859
# Epoch 4/200
# 77/77 [==============================] - 0s 3ms/step - loss: 1.0376 - accuracy: 0.5924
# Epoch 5/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8678 - accuracy: 0.6263
# Epoch 6/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7723 - accuracy: 0.6198
# Epoch 7/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7391 - accuracy: 0.6237
# Epoch 8/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7103 - accuracy: 0.6419
# Epoch 9/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.6380
# Epoch 10/200
# ...

# %%
# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4932 - accuracy: 0.7578
#
#  Accuracy: 0.7578
