# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2022_DataScience/blob/main/2022%EB%85%84_1%ED%95%99%EA%B8%B0_%EC%8B%9C%ED%97%98%EB%AC%B8%EC%A0%9C%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2022년 2학년 1학기 데이터과학과 머신러닝 수행평가(50점)입니다.(10점-보고서, 10점-출결,수업태도, 30점-기말지필)

# %% [markdown]
# # 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출

# %%
#문제1번(5점)

# %% [markdown]
# #폰트설치

# %%
#문제2번(5점)

# %% [markdown]
# #구글드라이브 마운트

# %%
#문제3번(5점)

# %% [markdown]
# #서울의 지역구별 동물병원파일(pet.xlsx)을 읽는다.

# %%
#문제4번(5점)

# %% [markdown]
# #도로명 주소에서 구 이름만 추출하여 '지역구' 칼럼을 만든다.
# df['지역구'] = df['도로명주소'].str.split(' ').str[1]

# %%
#문제5번(5점)

# %% [markdown]
# #지역구별로 숫자를 세서 새로운 데이터프레임을 만든다.
# df1=df.groupby('지역구').count()

# %%
#문제6번(5점)

# %% [markdown]
# #새로 만들어진 데이터프레임을 지역구별로 개수가 많은 구부터 내림차순으로 정렬한다.
# df1=df1.sort_values(by='사업장명', ascending=False)

# %%
#문제7번(5점)

# %% [markdown]
# #그림처럼 막대그래프로 시각화한다.
# ![20220520_070741.png](data:image/png;base64,...)

# %%
#문제8번(5점)

# %% [markdown]
# #동물병원의 위도와 경도를 이용하여 지도에 그림처럼 표시한다.
# ![20220520_071006.png](data:image/png;base64,...)

# %%
#문제9번(10점)
