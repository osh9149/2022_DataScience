# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2022_DataScience/blob/main/2022%EB%85%84_1%ED%95%99%EA%B8%B0(50%EC%A0%90)_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2022년 2학년 1학기 데이터과학과 머신러닝 수행평가(50점)입니다.(10점-보고서/ 10점-출결,수업태도/30점-기말지필)

# %% [markdown]
# # 문제1. 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출(2점)

# %%
#문제1번(2점)

# %% [markdown]
# #문제2. 폰트설치(2점)

# %%
#문제2번(2점)

# %% [markdown]
# #문제3. 구글드라이브 마운트(1점)

# %%
#문제3번(1점)

# %% [markdown]
# #문제4. 서울의 지역구별 따릉이 대여소 정보파일(seoul_bike.xlsx)을 읽는다.(5점)

# %%
#문제4번(5점)

# %% [markdown]
# #문제5. 주소에서 구 이름만 추출하여 '지역구' 칼럼을 만든다.(5점)

# %%
#문제5번(5점)

# %% [markdown]
# #문제6. 지역구별로 개수를 세서 새로운 데이터프레임을 만든다.(5점)

# %%
#문제6번(5점)

# %% [markdown]
# #문제7. 따릉이 대여소가 가장 많은 구와 가장 적은 구를 print문을 이용하여 다음과 같이 출력한다.(5점)
# idxmax, idxmin , print 문을 사용할 것
#
# 출력결과-> 따릉이 대여소가 가장 많은 구는 송파구이며 가장 적은 구는 강북구입니다.

# %%
#문제7번(5점)

# %% [markdown]
# #문제8. 새로 만들어진 데이터프레임을 지역구별로 개수가 많은 구부터 내림차순으로 정렬한다.(5점)

# %%
#문제8번(5점)

# %% [markdown]
# #문제9. 위의 데이터프레임을 그래프로 그림처럼 시각화한다.(5점)
# ![20220523_082330.png](data:image/png;base64,...)

# %%
#문제9번(5점)

# %% [markdown]
# #문제10. 데이터프레임의 위도, 경도 데이터를 이용하여 지도로 시각화한다.(10점)
# ![20220523_082415.png](data:image/png;base64,...)

# %%
#문제10번(10점)
